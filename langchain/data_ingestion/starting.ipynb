# %%
import os
from dotenv import load_dotenv
load_dotenv()
os.environ["LANGCHAIN_APIT_KEY"]= os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_PROJECT"]= os.getenv("LANGCHAIN_PROJECT")
os.environ["LANGCHAIN_TRACING_V2"]= os.getenv("LANGCHAIN_TRACING_V2")

# %%
from langchain_ollama import ChatOllama
llm=ChatOllama(model="gemma:2b")
llm
# Out:
# ChatOllama(metadata={'lc_versions': {'langchain-core': '1.6.4', 'langchain': '1.4.2'}}, model='gemma:2b')

# %%
result=llm.invoke("What is generative ai?")
result
# Out:
# AIMessage(content="Sure, here's a definition of generative AI:\n\n**Generative AI** is a type of artificial intelligence (AI) that creates new content, such as text, images, music, and videos, based on existing data. These models learn patterns and relationships in data and use these patterns to generate new content that is similar to the training data.\n\n**Key characteristics of generative AI include:**\n\n* **Content creation:** It can create novel and original content, such as poems, scripts, and paintings.\n* **Data-driven:** It relies heavily on data to learn and generate new content.\n* **Learning from data:** Generative AI models continuously learn from and adapt to new data, improving their ability to create high-quality content.\n* **Different modalities:** It can generate content in various formats, including text, images, audio, and video.\n\n**Examples of generative AI models include:**\n\n* **Chatbots:** Chatbots that can engage in natural language conversations.\n* **I
# ...

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt=ChatPromptTemplate.from_messages(
    [
        ("system", "Behave like a assistant and answer the question carefully.."),
        ("user", "{input}")
    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Behave like a assistant and answer the question carefully..'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain=prompt|llm
response=chain.invoke({"input":"Can you tell me about Langchain?"})
response
# Out:
# AIMessage(content="Sure, here is a summary of LangChain:\n\n**LangChain** is a decentralized, open-source platform designed to solve the challenges of data scarcity, censorship, and privacy in the crypto industry. It's a novel solution that uses smart contracts to incentivize users to share and monetize their data while preserving their privacy.\n\n**Key features of LangChain include:**\n\n* **Decentralized Data Storage:** Data is stored on a distributed network of nodes, eliminating reliance on centralized authorities like central exchanges or oracles.\n* **Privacy-Preserving Data Sharing:** Users can choose what data they want to share and control who can access it, ensuring privacy and control over their data.\n* **Data Monetization:** Users can earn money by participating in the LangChain ecosystem, including data monetization, liquidity mining, and staking.\n* **Smart Contract Governance:** The LangChain governance system allows token holders to participate in decision-making pr
# ...

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
chain=prompt|llm|output_parser
response=chain.invoke({"input":"Can you tell me about Langchain?"})
response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from langchain_core.output_parsers import StrOutputParser
#       2 output_parser=StrOutputParser()
# ----> 3 chain=prompt|llm|output_parser
#       4 response=chain.invoke({"input":"Can you tell me about Langchain?"})
#       5 response
#
# NameError: name 'prompt' is not defined
