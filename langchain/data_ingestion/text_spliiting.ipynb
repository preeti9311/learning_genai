# %%
from langchain_community.document_loaders import PyPDFLoader
loader_pdf=PyPDFLoader('cpp_oa_notes.pdf')
docs=loader_pdf.load()
# Out:
# C:\Users\preet\AppData\Local\Temp\ipykernel_10896\475728306.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %%
docs
# Out:
# [Document(metadata={'producer': 'Qt 5.15.13', 'creator': 'wkhtmltopdf 0.12.6', 'creationdate': '2026-09-13T10:22:01+00:00', 'title': '', 'source': 'cpp_oa_notes.pdf', 'total_pages': 8, 'page': 0, 'page_label': '1'}, page_content='C\t/\tC++\tTheory\t—\tIBM\tOA\tNotes\nDefinition\t→\tExample\t→\tImportant\tDifference\t→\tExam\tTrap\n1.\tPointer\tkya\thota\thai?\nPointer\tek\tvariable\thota\thai\tjo\tkisi\tdoosre\tvariable\tka\tmemory\taddress\tstore\tkarta\thai.\nint\tx\t=\t10;\nint\t*p\t=\t&x;\nYahan:\nx\n\t→\tvalue\t10\n&x\n\t→\tx\tka\taddress\np\n\t→\tx\tka\taddress\tstore\tkarta\thai\n*p\n\t→\tus\taddress\tpar\tstored\tvalue,\tyani\t10\nImportant\toperators\n&\n\t→\taddress-of\toperator\n*\n\t→\tdereference\toperator\ncout\t<<\tp;\t\t\t\t//\taddress\ncout\t<<\t*p;\t\t\t//\tvalue\n2.\tDangling\tPointer\t\n\x01\n\x01\nA\tdangling\tpointer\twoh\tpointer\thai\tjo\tkisi\taise\tmemory\tlocation\tko\tpoint\tkar\traha\thai\tjo\talready\tdeallocated/free\tho\tchuki\thai.\nExample:\nint\t*p\
# ...

# %%
## how to recursively split text by character
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)
final_documents=text_splitter.split_documents(docs)

# %%
print(final_documents[0])
print(final_documents[1])
# Out:
# page_content='C	/	C++	Theory	—	IBM	OA	Notes
# Definition	→	Example	→	Important	Difference	→	Exam	Trap
# 1.	Pointer	kya	hota	hai?
# Pointer	ek	variable	hota	hai	jo	kisi	doosre	variable	ka	memory	address	store	karta	hai.
# int	x	=	10;
# int	*p	=	&x;
# Yahan:
# x
# 	→	value	10
# &x
# 	→	x	ka	address
# p
# 	→	x	ka	address	store	karta	hai
# *p
# 	→	us	address	par	stored	value,	yani	10
# Important	operators
# &
# 	→	address-of	operator
# *
# 	→	dereference	operator
# cout	<<	p;				//	address
# cout	<<	*p;			//	value
# 2.	Dangling	Pointer
#
#
# A	dangling	pointer	woh	pointer	hai	jo	kisi	aise	memory	location	ko	point	kar	raha	hai	jo	already	deallocated/free	ho	chuki	hai.
# Example:
# int	*p	=	new	int(10);
# delete	p;
# //	p	is	now	dangling
# delete	p
# 	ke	baad	memory	free	ho	gayi,	lekin	p	abhi	bhi	purane	address	ko	contain	karta	hai.
# Avoid:
# delete	p;
# p	=	nullptr;
# Exam	definition:	A	dangling	pointer	points	to	memory	that	has	already	been	freed	or	is	no	longer	valid.
# ...

# %%
print("Original documents:", len(docs))
print("Final chunks:", len(final_documents))
# Out:
# Original documents: 8
# Final chunks: 20

# %%
from langchain_community.document_loaders import TextLoader
loader=TextLoader('speech.txt')
docs=loader.load()
docs
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='In modern AI applications, data ingestion plays a critical role. For example, in Retrieval-Augmented Generation (RAG) systems, documents are ingested, cleaned, chunked, converted into embeddings, and stored in a vector database so that an AI model can retrieve relevant information when answering user questions.\n\nSome popular tools used for data ingestion include Apache Kafka, Apache NiFi, Airbyte, Fivetran, AWS Glue, and Azure Data Factory.\n\nThe quality of any data-driven system depends heavily on the quality of its data ingestion process. If incorrect, incomplete, or outdated data enters the system, the results produced by analytics or AI models may also be inaccurate.\n\nIn conclusion, data ingestion is the foundation of the data lifecycle. It ensures that data flows from various sources into systems where it can create value through reporting, analytics, machine learning, and artificial intelligence.\n\nThere are two m
# ...

# %%
speech=""
with open("speech.txt")as f:
    speech=f.read()
speech
# Out:
# 'In modern AI applications, data ingestion plays a critical role. For example, in Retrieval-Augmented Generation (RAG) systems, documents are ingested, cleaned, chunked, converted into embeddings, and stored in a vector database so that an AI model can retrieve relevant information when answering user questions.\n\nSome popular tools used for data ingestion include Apache Kafka, Apache NiFi, Airbyte, Fivetran, AWS Glue, and Azure Data Factory.\n\nThe quality of any data-driven system depends heavily on the quality of its data ingestion process. If incorrect, incomplete, or outdated data enters the system, the results produced by analytics or AI models may also be inaccurate.\n\nIn conclusion, data ingestion is the foundation of the data lifecycle. It ensures that data flows from various sources into systems where it can create value through reporting, analytics, machine learning, and artificial intelligence.\n\nThere are two main types of data ingestion:\n\nBatch Ingestion – Data is 
# ...

# %%
text_splitter=RecursiveCharacterTextSplitter(chunk_size=100,chunk_overlap=40)
text=text_splitter.create_documents([speech])
print(text)
# Out:
# [Document(metadata={}, page_content='In modern AI applications, data ingestion plays a critical role. For example, in Retrieval-Augmented'), Document(metadata={}, page_content='For example, in Retrieval-Augmented Generation (RAG) systems, documents are ingested, cleaned,'), Document(metadata={}, page_content='documents are ingested, cleaned, chunked, converted into embeddings, and stored in a vector'), Document(metadata={}, page_content='into embeddings, and stored in a vector database so that an AI model can retrieve relevant'), Document(metadata={}, page_content='that an AI model can retrieve relevant information when answering user questions.'), Document(metadata={}, page_content='Some popular tools used for data ingestion include Apache Kafka, Apache NiFi, Airbyte, Fivetran,'), Document(metadata={}, page_content='Kafka, Apache NiFi, Airbyte, Fivetran, AWS Glue, and Azure Data Factory.'), Document(metadata={}, page_content='The quality of any data-driven system depends heavily on 
# ...

# %%
print(text[0])
# Out:
# page_content='In modern AI applications, data ingestion plays a critical role. For example, in Retrieval-Augmented'

# %%
print(text[1])
# Out:
# page_content='For example, in Retrieval-Augmented Generation (RAG) systems, documents are ingested, cleaned,'
